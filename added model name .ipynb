# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('next step.csv')
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (14,43) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#                          Name      Price  Model Year   Mileage  \
# 0       Adam Revo 1051cc 2006   210000.0      2006.0  100000.0
# 1              Adam Revo 2006   290000.0      2006.0   58000.0
# 2         Adam Zabardast 2009  1000000.0      2009.0  300000.0
# 3                Audi A1 2012  4500000.0      2012.0   36000.0
# 4       Audi A3 1.2 TFSI 2015  4495000.0      2015.0    5599.0
# ...                       ...        ...         ...       ...
# 54480      Volkswagen Up 2015  1550000.0      2015.0   32000.0
# 54481      Volkswagen Up 2016  2349000.0      2016.0   27800.0
# 54482  Volvo S40 Kinetic 1998  1275000.0      1998.0  145000.0
# 54483                     NaN        NaN         NaN       NaN
# 54484                     NaN        NaN         NaN       NaN
#
#       Registered City Engine Type Engine Capacity Transmission   Color  \
# 0             Karachi      Petrol         1000 cc       Manual  Orange
# 1             Karachi         NaN          800 cc       Manual     Red
# 2             Karachi      Diesel         3000 cc       Manual  Yellow
# 3           Hyderabad      Petrol         1000 cc       Manual  Silver
# 4              Lahore      Petrol         1200 cc    Automatic  Silver
# ...               ...         ...             ...          ...     ...
# 54480          Lahore      Petrol         1000 cc    Automatic  Silver
# 54481          Lahore      Petrol         1000 cc    Automatic  Silver
# 54482       Islamabad      Petrol         1600 cc    Automatic    Blue
# 54483             NaN         NaN             NaN          NaN     NaN
# 54484             NaN         NaN             NaN          NaN     NaN
#
#        Assembly  ... Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  \
# 0         Local  ...         NaN          NaN          NaN          NaN
# 1         Local  ...         NaN          NaN          NaN          NaN
# 2         Local  ...         NaN          NaN          NaN          NaN
# 3      Imported  ...         NaN          NaN          NaN          NaN
# 4      Imported  ...         NaN          NaN          NaN          NaN
# ...         ...  ...         ...          ...          ...          ...
# 54480  Imported  ...         NaN          NaN          NaN          NaN
# 54481  Imported  ...         NaN          NaN          NaN          NaN
# 54482  Imported  ...         NaN          NaN          NaN          NaN
# 54483       NaN  ...         NaN          NaN          NaN          NaN
# 54484       NaN  ...         NaN          NaN          NaN          NaN
#
#       Unnamed: 39  Unnamed: 40     Company             Model Name  \
# 0             NaN          NaN        Adam  Revo 1051cc 2006
# 1             NaN          NaN        Adam        Revo 2006
# 2             NaN          NaN        Adam   Zabardast 2009
# 3             NaN          NaN        Audi          A1 2012
# 4             NaN          NaN        Audi   A3 1.2 TFSI 2015
# ...           ...          ...         ...                    ...
# 54480         NaN          NaN  Volkswagen          Up 2015
# 54481         NaN          NaN  Volkswagen          Up 2016
# 54482         NaN          NaN       Volvo  S40 Kinetic 1998
# 54483         NaN          NaN         NaN
# 54484         NaN          NaN         NaN
#
#        Unnamed: 43  Unnamed: 44
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# ...            ...          ...
# 54480          NaN          NaN
# 54481          NaN          NaN
# 54482          NaN          NaN
# 54483          NaN          NaN
# 54484          NaN          NaN
#
# [54485 rows x 45 columns]

# %%
df2=df[['Price','Model Year','Mileage','Registered City','Engine Type','Engine Capacity','Transmission','Color',
       'Assembly','Features','Company','Model Name']]

# %%
df2
# Out:
#            Price  Model Year   Mileage Registered City Engine Type  \
# 0       210000.0      2006.0  100000.0         Karachi      Petrol
# 1       290000.0      2006.0   58000.0         Karachi         NaN
# 2      1000000.0      2009.0  300000.0         Karachi      Diesel
# 3      4500000.0      2012.0   36000.0       Hyderabad      Petrol
# 4      4495000.0      2015.0    5599.0          Lahore      Petrol
# ...          ...         ...       ...             ...         ...
# 54480  1550000.0      2015.0   32000.0          Lahore      Petrol
# 54481  2349000.0      2016.0   27800.0          Lahore      Petrol
# 54482  1275000.0      1998.0  145000.0       Islamabad      Petrol
# 54483        NaN         NaN       NaN             NaN         NaN
# 54484        NaN         NaN       NaN             NaN         NaN
#
#       Engine Capacity Transmission   Color  Assembly  \
# 0             1000 cc       Manual  Orange     Local
# 1              800 cc       Manual     Red     Local
# 2             3000 cc       Manual  Yellow     Local
# 3             1000 cc       Manual  Silver  Imported
# 4             1200 cc    Automatic  Silver  Imported
# ...               ...          ...     ...       ...
# 54480         1000 cc    Automatic  Silver  Imported
# 54481         1000 cc    Automatic  Silver  Imported
# 54482         1600 cc    Automatic    Blue  Imported
# 54483             NaN          NaN     NaN       NaN
# 54484             NaN          NaN     NaN       NaN
#
#                                                 Features     Company  \
# 0                                                    NaN        Adam
# 1                                                    NaN        Adam
# 2       AM/FM Radio, Air Conditioning, Alloy Rims, CD...        Adam
# 3       AM/FM Radio, Air Bags, Front Camera, Power Mi...        Audi
# 4       ABS, AM/FM Radio, Air Bags, Air Conditioning,...        Audi
# ...                                                  ...         ...
# 54480   ABS, AM/FM Radio, Air Bags, Air Conditioning,...  Volkswagen
# 54481   ABS, AM/FM Radio, Air Bags, Air Conditioning,...  Volkswagen
# 54482                                                NaN       Volvo
# 54483                                                NaN         NaN
# 54484                                                NaN         NaN
#
#                   Model Name
# 0      Revo 1051cc 2006
# 1            Revo 2006
# 2       Zabardast 2009
# 3              A1 2012
# 4       A3 1.2 TFSI 2015
# ...                      ...
# 54480          Up 2015
# 54481          Up 2016
# 54482  S40 Kinetic 1998
# 54483
# 54484
#
# [54485 rows x 12 columns]

# %%
data=df2.dropna()
data
# Out:
#            Price  Model Year   Mileage Registered City Engine Type  \
# 2      1000000.0      2009.0  300000.0         Karachi      Diesel
# 3      4500000.0      2012.0   36000.0       Hyderabad      Petrol
# 4      4495000.0      2015.0    5599.0          Lahore      Petrol
# 5      5700000.0      2017.0   45000.0          Lahore      Petrol
# 6      5700000.0      2017.0   12000.0       Islamabad      Petrol
# ...          ...         ...       ...             ...         ...
# 54474  3000000.0      2013.0   78000.0       Islamabad      Petrol
# 54478  2075000.0      2014.0   99000.0       Islamabad      Petrol
# 54479  2250000.0      2014.0   57000.0         Karachi      Petrol
# 54480  1550000.0      2015.0   32000.0          Lahore      Petrol
# 54481  2349000.0      2016.0   27800.0          Lahore      Petrol
#
#       Engine Capacity Transmission   Color  Assembly  \
# 2             3000 cc       Manual  Yellow     Local
# 3             1000 cc       Manual  Silver  Imported
# 4             1200 cc    Automatic  Silver  Imported
# 5             1200 cc    Automatic   White     Local
# 6             1200 cc    Automatic   White     Local
# ...               ...          ...     ...       ...
# 54474         1200 cc    Automatic   White  Imported
# 54478         1000 cc    Automatic   Black  Imported
# 54479         1000 cc    Automatic   White  Imported
# 54480         1000 cc    Automatic  Silver  Imported
# 54481         1000 cc    Automatic  Silver  Imported
#
#                                                 Features     Company  \
# 2       AM/FM Radio, Air Conditioning, Alloy Rims, CD...        Adam
# 3       AM/FM Radio, Air Bags, Front Camera, Power Mi...        Audi
# 4       ABS, AM/FM Radio, Air Bags, Air Conditioning,...        Audi
# 5       ABS, AM/FM Radio, Air Bags, Air Conditioning,...        Audi
# 6       ABS, AM/FM Radio, Air Bags, Air Conditioning,...        Audi
# ...                                                  ...         ...
# 54474   ABS, AM/FM Radio, Air Bags, Air Conditioning,...  Volkswagen
# 54478   ABS, AM/FM Radio, Air Bags, Air Conditioning,...  Volkswagen
# 54479   Air Bags, Air Conditioning, Power Locks, Powe...  Volkswagen
# 54480   ABS, AM/FM Radio, Air Bags, Air Conditioning,...  Volkswagen
# 54481   ABS, AM/FM Radio, Air Bags, Air Conditioning,...  Volkswagen
#
#                  Model Name
# 2      Zabardast 2009
# 3             A1 2012
# 4      A3 1.2 TFSI 2015
# 5      A3 1.2 TFSI 2017
# 6      A3 1.2 TFSI 2017
# ...                     ...
# 54474       Polo 2013
# 54478         Up 2014
# 54479         Up 2014
# 54480         Up 2015
# 54481         Up 2016
#
# [48262 rows x 12 columns]

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
fig, ax = plt.subplots(figsize=(22,11))
g=sns.countplot(x='Company',data=data,dodge=False,ax=ax,
                  palette=(sns.color_palette("hls", 8) + 
                           sns.color_palette("Paired") + 
                           sns.color_palette(flatui)))
g.legend(loc='upper center', ncol=3)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
fig, ax = plt.subplots(figsize=(22,10))
g=sns.countplot(x='Color',data=data,dodge=False,ax=ax,
                  palette=(sns.color_palette("hls", 8) + 
                           sns.color_palette("Paired") + 
                           sns.color_palette(flatui)))
g.legend(loc='upper center', ncol=3)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
fig, ax = plt.subplots(figsize=(22,10))
g=sns.countplot(x='Transmission',data=data,dodge=False,ax=ax,
                  palette=(sns.color_palette("hls", 8) + 
                           sns.color_palette("Paired") + 
                           sns.color_palette(flatui)))
g.legend(loc='upper center', ncol=3)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
fig, ax = plt.subplots(figsize=(42,12))
g=sns.countplot(x='Engine Capacity',data=data,dodge=False,ax=ax,
                  palette=(sns.color_palette("hls", 8) + 
                           sns.color_palette("Paired") + 
                           sns.color_palette(flatui)))
g.legend(loc='upper center', ncol=3)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
fig, ax = plt.subplots(figsize=(32,12))
g=sns.countplot(x='Registered City',data=data,dodge=False,ax=ax,
                  palette=(sns.color_palette("hls", 8) + 
                           sns.color_palette("Paired") + 
                           sns.color_palette(flatui)))
g.legend(loc='upper center', ncol=3)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(figsize=(32,12))
sns.distplot(data['Price'])

# %%
fig, ax = plt.subplots(figsize=(32,2))
sns.jointplot(x='Model Year',y='Price',data=data,kind='reg')

# %%
fig, ax = plt.subplots(figsize=(32,2))

sns.pairplot(data,palette='coolwarm')

# %%
sns.heatmap(data.corr(),cmap='coolwarm',annot=True)

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
fig, ax = plt.subplots(figsize=(70,10))
g=sns.countplot(x='Model Name',data=data,dodge=False,ax=ax,
                  palette=(sns.color_palette("hls", 8) + 
                           sns.color_palette("Paired") + 
                           sns.color_palette(flatui)))
g.legend(loc='upper center', ncol=3)
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(22,6))
sns.lmplot(x='Mileage',y='Price',data=data,hue='Assembly',markers=['o','v'],scatter_kws={'s':100})

# %%
sns.lmplot(x='Model Year',y='Price',data=data,hue='Assembly',markers=['o','v'],scatter_kws={'s':100})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6cbbf17fca13> in <module>
# ----> 1 sns.lmplot(x='Model Year',y='Price',data=data,hue='Assembly',markers=['o','v'],scatter_kws={'s':100})
#
# NameError: name 'data' is not defined
